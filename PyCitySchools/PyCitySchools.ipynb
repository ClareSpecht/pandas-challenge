# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Calculate total number of schools
schools = len(school_data)

#Calculate total number of students
students = len(student_data)

#Calculate total budget
budget = school_data["budget"].sum()

#Calculate average math score
mathscore = student_data["math_score"].mean()

#Calculate average reading score
readscore = student_data["reading_score"].mean()

#Calculate percentage of students with passing math score
mathpass = len(student_data.loc[student_data["math_score"] >= 70])
percentmathpass = mathpass / students * 100

#Calculate percentage of students with passing reading score
readpass = len(student_data.loc[student_data["reading_score"] >= 70])
percentreadpass = readpass / students * 100

#Calculate percentage of students with passing math and reading scores
overallpass = len(student_data.loc[(student_data["reading_score"] >= 70) & (student_data["math_score"] >= 70)])
percentoverallpass = overallpass / students * 100

#Create dataframe to hold results
districtsum = pd.DataFrame({"Total Schools" : [schools], "Total Students" : [students], "Total Budget" : budget, 
                            "Average Math Score" : mathscore, "Average Reading Score" : readscore, "% Passing Math" : 
                            percentmathpass, "% Passing Reading" : percentreadpass, "% Overall Passing" : 
                            percentoverallpass})

#Format data
districtsum.style.format(formatter = {"Total Students" : "{:,.0f}", "Total Budget" : "${:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a4f70_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Schools</th>
#       <th class="col_heading level0 col1" >Total Students</th>
#       <th class="col_heading level0 col2" >Total Budget</th>
#       <th class="col_heading level0 col3" >Average Math Score</th>
#       <th class="col_heading level0 col4" >Average Reading Score</th>
#       <th class="col_heading level0 col5" >% Passing Math</th>
#       <th class="col_heading level0 col6" >% Passing Reading</th>
#       <th class="col_heading level0 col7" >% Overall Passing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4f70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4f70_row0_col0" class="data row0 col0" >15</td>
#       <td id="T_a4f70_row0_col1" class="data row0 col1" >39,170</td>
#       <td id="T_a4f70_row0_col2" class="data row0 col2" >$24,649,428.00</td>
#       <td id="T_a4f70_row0_col3" class="data row0 col3" >78.985371</td>
#       <td id="T_a4f70_row0_col4" class="data row0 col4" >81.877840</td>
#       <td id="T_a4f70_row0_col5" class="data row0 col5" >74.980853</td>
#       <td id="T_a4f70_row0_col6" class="data row0 col6" >85.805463</td>
#       <td id="T_a4f70_row0_col7" class="data row0 col7" >65.172326</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#Rename column in case we'd like index name to show up
newschool = school_data.rename(columns={"school_name" : "School Name"})
newstudent = student_data.rename(columns={"school_name" : "School Name"})

#Group by school name
groupedschool = newschool.groupby(["School Name"])
groupedstudent = newstudent.groupby(["School Name"])

#Generate school type per school
schooltype = groupedschool["type"].unique()

#Pull school type out of list generated by unique command
for x in range(len(schooltype)):
    array = schooltype[x]
    schooltype[x] = array[0]

#Count students at each school
studentcount = groupedstudent["student_name"].count()

#Calculate budget at each school
budgetsum = groupedschool["budget"].sum()

#Calculate budget per student at each school
perstudent = budgetsum / studentcount

#Calculate average math score per school
schoolmath = groupedstudent["math_score"].mean()

#Calculate average reading score per school
schoolread = groupedstudent["reading_score"].mean()

#Calculate percentage of students with passing math score
schoolmathpass = newstudent.loc[newstudent["math_score"] >= 70]
groupedmath = schoolmathpass.groupby(["School Name"])
mathpassschool = ((groupedmath["math_score"]).count() / studentcount) * 100

#Calculate percentage of students with passing reading score
schoolreadpass = newstudent.loc[newstudent["reading_score"] >= 70]
groupedread = schoolreadpass.groupby(["School Name"])
readpassschool = ((groupedread["reading_score"]).count() / studentcount) * 100

#Calculate percentage of students with passing overall score
schooloverpass = newstudent.loc[(newstudent["reading_score"] >= 70) & (student_data["math_score"] >= 70)]
groupedover = schooloverpass.groupby(["School Name"])
overpassschool = ((groupedover["reading_score"]).count() / studentcount) * 100

#Create dataframe to hold results
schoolsummary = pd.DataFrame({"School Type" : schooltype,
                              "Total Students" : studentcount,
                              "Total School Budget" : budgetsum, 
                              "Per Student Budget" : perstudent,
                              "Average Math Score" : schoolmath, 
                              "Average Reading Score" : schoolread, 
                              "% Passing Math" : mathpassschool, 
                              "% Passing Reading" : readpassschool, 
                              "% Overall Passing" : overpassschool})

#Use to hide "School Name" to match starter file
schoolsummary.index.name = None

#Format dataframe
schoolsummary.style.format(formatter = {"Total School Budget" : "${:,.2f}", "Per Student Budget" : "${:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_832ff_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >School Type</th>
#       <th class="col_heading level0 col1" >Total Students</th>
#       <th class="col_heading level0 col2" >Total School Budget</th>
#       <th class="col_heading level0 col3" >Per Student Budget</th>
#       <th class="col_heading level0 col4" >Average Math Score</th>
#       <th class="col_heading level0 col5" >Average Reading Score</th>
#       <th class="col_heading level0 col6" >% Passing Math</th>
#       <th class="col_heading level0 col7" >% Passing Reading</th>
#       <th class="col_heading level0 col8" >% Overall Passing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_832ff_level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#       <td id="T_832ff_row0_col0" class="data row0 col0" >District</td>
#       <td id="T_832ff_row0_col1" class="data row0 col1" >4976</td>
#       <td id="T_832ff_row0_col2" class="data row0 col2" >$3,124,928.00</td>
#       <td id="T_832ff_row0_col3" class="data row0 col3" >$628.00</td>
#       <td id="T_832ff_row0_col4" class="data row0 col4" >77.048432</td>
#       <td id="T_832ff_row0_col5" class="data row0 col5" >81.033963</td>
#       <td id="T_832ff_row0_col6" class="data row0 col6" >66.680064</td>
#       <td id="T_832ff_row0_col7" class="data row0 col7" >81.933280</td>
#       <td id="T_832ff_row0_col8" class="data row0 col8" >54.642283</td>
#     </tr>
#     <tr>
#       <th id="T_832ff_level0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#       <td id="T_832ff_row1_col0" class="data row1 col0" >Charter</td>
#       <td id="T_832ff_row1_col1" class="data row1 col1" >1858</td>
#       <td id="T_832ff_row1_col2" class="data row1 col2" >$1,081,356.00</td>
#       <td id="T_832ff_row1_col3" class="data row1 col3" >$582.00</td>
#       <td id="T_832ff_row1_col4" class="data row1 col4" >83.061895</td>
#       <td id="T_832ff_row1_col5" class="data row1 col5" >83.975780</td>
#       <td id="T_832ff_row1_col6" class="data row1 col6" >94.133477</td>
#       <td id="T_832ff_row1_col7" class="data row1 col7" >97.039828</td>
#       <td id="T_832ff_row1_col8" class="data row1 col8" >91.334769</td>
#     </tr>
#     <tr>
#       <th id="T_832ff_level0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#       <td id="T_832ff_row2_col0" class="data row2 col0" >District</td>
#       <td id="T_832ff_row2_col1" class="data row2 col1" >2949</td>
#       <td id="T_832ff_row2_col2" class="data row2 col2" >$1,884,411.00</td>
#       <td id="T_832ff_row2_col3" class="data row2 col3" >$639.00</td>
#       <td id="T_832ff_row2_col4" class="data row2 col4" >76.711767</td>
#       <td id="T_832ff_row2_col5" class="data row2 col5" >81.158020</td>
#       <td id="T_832ff_row2_col6" class="data row2 col6" >65.988471</td>
#       <td id="T_832ff_row2_col7" class="data row2 col7" >80.739234</td>
#       <td id="T_832ff_row2_col8" class="data row2 col8" >53.204476</td>
#     </tr>
#     <tr>
#       <th id="T_832ff_level0_row3" class="row_heading level0 row3" >Ford High School</th>
#       <td id="T_832ff_row3_col0" class="data row3 col0" >District</td>
#       <td id="T_832ff_row3_col1" class="data row3 col1" >2739</td>
#       <td id="T_832ff_row3_col2" class="data row3 col2" >$1,763,916.00</td>
#       <td id="T_832ff_row3_col3" class="data row3 col3" >$644.00</td>
#       <td id="T_832ff_row3_col4" class="data row3 col4" >77.102592</td>
#       <td id="T_832ff_row3_col5" class="data row3 col5" >80.746258</td>
#       <td id="T_832ff_row3_col6" class="data row3 col6" >68.309602</td>
#       <td id="T_832ff_row3_col7" class="data row3 col7" >79.299014</td>
#       <td id="T_832ff_row3_col8" class="data row3 col8" >54.289887</td>
#     </tr>
#     <tr>
#       <th id="T_832ff_level0_row4" class="row_heading level0 row4" >Griffin High School</th>
#       <td id="T_832ff_row4_col0" class="data row4 col0" >Charter</td>
#       <td id="T_832ff_row4_col1" class="data row4 col1" >1468</td>
#       <td id="T_832ff_row4_col2" class="data row4 col2" >$917,500.00</td>
#       <td id="T_832ff_row4_col3" class="data row4 col3" >$625.00</td>
#       <td id="T_832ff_row4_col4" class="data row4 col4" >83.351499</td>
#       <td id="T_832ff_row4_col5" class="data row4 col5" >83.816757</td>
#       <td id="T_832ff_row4_col6" class="data row4 col6" >93.392371</td>
#       <td id="T_832ff_row4_col7" class="data row4 col7" >97.138965</td>
#       <td id="T_832ff_row4_col8" class="data row4 col8" >90.599455</td>
#     </tr>
#     <tr>
#       <th id="T_832ff_level0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#       <td id="T_832ff_row5_col0" class="data row5 col0" >District</td>
#       <td id="T_832ff_row5_col1" class="data row5 col1" >4635</td>
#       <td id="T_832ff_row5_col2" class="data row5 col2" >$3,022,020.00</td>
#       <td id="T_832ff_row5_col3" class="data row5 col3" >$652.00</td>
#       <td id="T_832ff_row5_col4" class="data row5 col4" >77.289752</td>
#       <td id="T_832ff_row5_col5" class="data row5 col5" >80.934412</td>
#       <td id="T_832ff_row5_col6" class="data row5 col6" >66.752967</td>
#       <td id="T_832ff_row5_col7" class="data row5 col7" >80.862999</td>
#       <td id="T_832ff_row5_col8" class="data row5 col8" >53.527508</td>
#     </tr>
#     <tr>
#       <th id="T_832ff_level0_row6" class="row_heading level0 row6" >Holden High School</th>
#       <td id="T_832ff_row6_col0" class="data row6 col0" >Charter</td>
#       <td id="T_832ff_row6_col1" class="data row6 col1" >427</td>
#       <td id="T_832ff_row6_col2" class="data row6 col2" >$248,087.00</td>
#       <td id="T_832ff_row6_col3" class="data row6 col3" >$581.00</td>
#       <td id="T_832ff_row6_col4" class="data row6 col4" >83.803279</td>
#       <td id="T_832ff_row6_col5" class="data row6 col5" >83.814988</td>
#       <td id="T_832ff_row6_col6" class="data row6 col6" >92.505855</td>
#       <td id="T_832ff_row6_col7" class="data row6 col7" >96.252927</td>
#       <td id="T_832ff_row6_col8" class="data row6 col8" >89.227166</td>
#     </tr>
#     <tr>
#       <th id="T_832ff_level0_row7" class="row_heading level0 row7" >Huang High School</th>
#       <td id="T_832ff_row7_col0" class="data row7 col0" >District</td>
#       <td id="T_832ff_row7_col1" class="data row7 col1" >2917</td>
#       <td id="T_832ff_row7_col2" class="data row7 col2" >$1,910,635.00</td>
#       <td id="T_832ff_row7_col3" class="data row7 col3" >$655.00</td>
#       <td id="T_832ff_row7_col4" class="data row7 col4" >76.629414</td>
#       <td id="T_832ff_row7_col5" class="data row7 col5" >81.182722</td>
#       <td id="T_832ff_row7_col6" class="data row7 col6" >65.683922</td>
#       <td id="T_832ff_row7_col7" class="data row7 col7" >81.316421</td>
#       <td id="T_832ff_row7_col8" class="data row7 col8" >53.513884</td>
#     </tr>
#     <tr>
#       <th id="T_832ff_level0_row8" class="row_heading level0 row8" >Johnson High School</th>
#       <td id="T_832ff_row8_col0" class="data row8 col0" >District</td>
#       <td id="T_832ff_row8_col1" class="data row8 col1" >4761</td>
#       <td id="T_832ff_row8_col2" class="data row8 col2" >$3,094,650.00</td>
#       <td id="T_832ff_row8_col3" class="data row8 col3" >$650.00</td>
#       <td id="T_832ff_row8_col4" class="data row8 col4" >77.072464</td>
#       <td id="T_832ff_row8_col5" class="data row8 col5" >80.966394</td>
#       <td id="T_832ff_row8_col6" class="data row8 col6" >66.057551</td>
#       <td id="T_832ff_row8_col7" class="data row8 col7" >81.222432</td>
#       <td id="T_832ff_row8_col8" class="data row8 col8" >53.539172</td>
#     </tr>
#     <tr>
#       <th id="T_832ff_level0_row9" class="row_heading level0 row9" >Pena High School</th>
#       <td id="T_832ff_row9_col0" class="data row9 col0" >Charter</td>
#       <td id="T_832ff_row9_col1" class="data row9 col1" >962</td>
#       <td id="T_832ff_row9_col2" class="data row9 col2" >$585,858.00</td>
#       <td id="T_832ff_row9_col3" class="data row9 col3" >$609.00</td>
#       <td id="T_832ff_row9_col4" class="data row9 col4" >83.839917</td>
#       <td id="T_83

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
#Sort school summary df by highest to lowest overall passing %
topperformers = schoolsummary.sort_values("% Overall Passing", ascending=False)

#Display preview (i.e. only top five)
topperformers.head()
# Out:
#                     School Type  Total Students  Total School Budget  \
# Cabrera High School     Charter            1858              1081356
# Thomas High School      Charter            1635              1043130
# Griffin High School     Charter            1468               917500
# Wilson High School      Charter            2283              1319574
# Pena High School        Charter             962               585858
#
#                      Per Student Budget  Average Math Score  \
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# Thomas High School               83.848930       93.272171          97.308869
# Griffin High School              83.816757       93.392371          97.138965
# Wilson High School               83.989488       93.867718          96.539641
# Pena High School                 84.044699       94.594595          95.945946
#
#                      % Overall Passing
# Cabrera High School          91.334769
# Thomas High School           90.948012
# Griffin High School          90.599455
# Wilson High School           90.582567
# Pena High School             90.540541

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
#Sort school summary df by lowest to highest overall passing %
worstperformers = schoolsummary.sort_values("% Overall Passing")

#Display preview (i.e. only top five)
worstperformers.head()
# Out:
#                       School Type  Total Students  Total School Budget  \
# Rodriguez High School    District            3999              2547363
# Figueroa High School     District            2949              1884411
# Huang High School        District            2917              1910635
# Hernandez High School    District            4635              3022020
# Johnson High School      District            4761              3094650
#
#                        Per Student Budget  Average Math Score  \
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# Figueroa High School               81.158020       65.988471
# Huang High School                  81.182722       65.683922
# Hernandez High School              80.934412       66.752967
# Johnson High School                80.966394       66.057551
#
#                        % Passing Reading  % Overall Passing
# Rodriguez High School          80.220055          52.988247
# Figueroa High School           80.739234          53.204476
# Huang High School              81.316421          53.513884
# Hernandez High School          80.862999          53.527508
# Johnson High School            81.222432          53.539172

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
